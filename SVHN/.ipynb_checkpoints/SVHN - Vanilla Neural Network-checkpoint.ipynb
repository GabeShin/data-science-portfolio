# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from scipy.io import loadmat
from sklearn.utils import shuffle

from datetime import datetime

from utils import y2indicator, error_rate, getTrainData, getTestData

# %% [markdown]
# ## Load Data

# %%
Xtrain, Ytrain = getTrainData()
Xtest, Ytest = getTestData()

# %%
# parameter
learning_rate = 0.01
decay = 0.99
momentum = 0.9

# gradient descent params
max_iter = 20
print_period = 10
N, D = Xtrain.shape
batch_sz = 500
n_batches = N // batch_sz

# initial weights
M1 = 1000 # hidden layer size
M2 = 500
K = 10

# define weights and biases
W1_init = np.random.randn(D, M1) / np.sqrt(D + M1)
b1_init = np.zeros(M1)
W2_init = np.random.randn(M1, M2) / np.sqrt(M1 + M2)
b2_init = np.zeros(M2)
W3_init = np.random.randn(M2, K) / np.sqrt(M2 + K)
b3_init = np.zeros(K)

# %%
# set placeholder for X and T
X = tf.placeholder(tf.float32, shape = (None, D), name ='X')
T = tf.placeholder(tf.int32, shape=(None, ), name='T')

# Set up weight and biases variables 
W1 = tf.Variable(W1_init.astype(np.float32))
b1 = tf.Variable(b1_init.astype(np.float32))
W2 = tf.Variable(W2_init.astype(np.float32))
b2 = tf.Variable(b2_init.astype(np.float32))
W3 = tf.Variable(W3_init.astype(np.float32))
b3 = tf.Variable(b3_init.astype(np.float32))

# %%
# Vanilla Artifial Neural Network with 2 Hidden Layers
Z1 = tf.nn.relu( tf.matmul(X, W1) + b1 )
Z2 = tf.nn.relu( tf.matmul(Z1, W2) + b2 )
logits = tf.matmul(Z2, W3) + b3

# %%
# Define cost  - cross entropy
cost = tf.reduce_sum(
    tf.nn.sparse_softmax_cross_entropy_with_logits(
        logits=logits,
        labels=T
    )
)
# define train optimizer
train_op = tf.train.RMSPropOptimizer(0.0001, decay=0.99, momentum=0.9).minimize(cost)

# %%
# we'll use this to calculate the error rate
predict_op = tf.argmax(logits, 1)

t0 = datetime.now()
LL = []
init = tf.global_variables_initializer()
with tf.Session() as session:
    session.run(init)

    for i in range(max_iter):
        for j in range(n_batches):
            Xbatch = Xtrain[j*batch_sz:(j*batch_sz + batch_sz),]
            Ybatch = Ytrain[j*batch_sz:(j*batch_sz + batch_sz),]

            session.run(train_op, feed_dict={X: Xbatch, T: Ybatch})
            if j % print_period == 0:
                test_cost = session.run(cost, feed_dict={X: Xtest, T: Ytest})
                prediction = session.run(predict_op, feed_dict={X: Xtest})
                err = error_rate(prediction, Ytest)
                print("Cost / err at iteration i=%d, j=%d: %.3f / %.3f" % (i, j, test_cost, err))
                LL.append(test_cost)
print("Elapsed time:", (datetime.now() - t0))
plt.plot(LL)
plt.show()
# Out:
# Cost / err at iteration i=0, j=0: 58508.156 / 0.804
# Cost / err at iteration i=0, j=10: 58317.578 / 0.802
# Cost / err at iteration i=0, j=20: 58490.125 / 0.804
# Cost / err at iteration i=0, j=30: 58081.742 / 0.825
# Cost / err at iteration i=0, j=40: 57903.816 / 0.793
# Cost / err at iteration i=0, j=50: 57492.547 / 0.786
# Cost / err at iteration i=0, j=60: 56938.609 / 0.803
# Cost / err at iteration i=0, j=70: 55796.875 / 0.735
# Cost / err at iteration i=0, j=80: 54736.586 / 0.779
# Cost / err at iteration i=0, j=90: 52223.633 / 0.715
# Cost / err at iteration i=0, j=100: 52161.367 / 0.653
# Cost / err at iteration i=0, j=110: 50229.961 / 0.693
# Cost / err at iteration i=0, j=120: 48037.426 / 0.643
# Cost / err at iteration i=0, j=130: 44732.922 / 0.577
# Cost / err at iteration i=0, j=140: 43436.375 / 0.559
# Cost / err at iteration i=1, j=0: 46715.195 / 0.612
# Cost / err at iteration i=1, j=10: 44932.266 / 0.582
# Cost / err at iteration i=1, j=20: 44558.461 / 0.568
# Cost / err at iteration i=1, j=30: 40690.086 / 0.517
# Cost / err at iteration i=1, j=40: 39743.734 / 0.500
# Cost / err at iteration i=1, j=50: 39374.812 / 0.480
# Cost / err at iteration i=1, j=60: 38150.219 / 0.462
# Cost / err at iteration i=1, j=70: 36660.035 / 0.438
# Cost / err at iteration i=1, j=80: 37656.805 / 0.459
# Cost / err at iteration i=1, j=90: 36318.977 / 0.430
# Cost / err at iteration i=1, j=100: 35125.617 / 0.421
# Cost / err at iteration i=1, j=110: 36330.508 / 0.445
# Cost / err at iteration i=1, j=120: 36460.102 / 0.442
# Cost / err at iteration i=1, j=130: 35140.555 / 0.424
# Cost / err at iteration i=1, j=140: 34848.133 / 0.418
# Cost / err at iteration i=2, j=0: 35222.516 / 0.425
# Cost / err at iteration i=2, j=10: 35584.094 / 0.436
# Cost / err at iteration i=2, j=20: 34837.195 / 0.409
# Cost / err at iteration i=2, j=30: 33240.410 / 0.400
# Cost / err at iteration i=2, j=40: 32992.977 / 0.396
# Cost / err at iteration i=2, j=50: 32439.980 / 0.385
# Cost / err at iteration i=2, j=60: 32848.914 / 0.391
# Cost / err at iteration i=2, j=70: 32268.477 / 0.380
# Cost / err at iteration i=2, j=80: 33003.977 / 0.393
# Cost / err at iteration i=2, j=90: 31666.402 / 0.368
# Cost / err at iteration i=2, j=100: 30711.145 / 0.355
# Cost / err at iteration i=2, j=110: 31771.594 / 0.372
# Cost / err at iteration i=2, j=120: 32457.309 / 0.383
# Cost / err at iteration i=2, j=130: 32824.770 / 0.388
# Cost / err at iteration i=2, j=140: 30662.721 / 0.358
# Cost / err at iteration i=3, j=0: 33128.836 / 0.392
# Cost / err at iteration i=3, j=10: 31877.518 / 0.377
# Cost / err at iteration i=3, j=20: 31028.861 / 0.362
# Cost / err at iteration i=3, j=30: 30554.080 / 0.365
# Cost / err at iteration i=3, j=40: 30249.469 / 0.356
# Cost / err at iteration i=3, j=50: 29464.715 / 0.345
# Cost / err at iteration i=3, j=60: 29283.945 / 0.341
# Cost / err at iteration i=3, j=70: 30338.551 / 0.350
# Cost / err at iteration i=3, j=80: 30025.188 / 0.346
# Cost / err at iteration i=3, j=90: 29536.223 / 0.344
# Cost / err at iteration i=3, j=100: 29085.891 / 0.337
# Cost / err at iteration i=3, j=110: 30432.092 / 0.355
# Cost / err at iteration i=3, j=120: 29256.121 / 0.346
# Cost / err at iteration i=3, j=130: 30224.592 / 0.351
# Cost / err at iteration i=3, j=140: 28829.932 / 0.342
# Cost / err at iteration i=4, j=0: 29872.629 / 0.346
# Cost / err at iteration i=4, j=10: 28256.566 / 0.321
# Cost / err at iteration i=4, j=20: 27991.805 / 0.322
# Cost / err at iteration i=4, j=30: 27918.941 / 0.331
# Cost / err at iteration i=4, j=40: 28793.852 / 0.336
# Cost / err at iteration i=4, j=50: 27839.156 / 0.324
# Cost / err at iteration i=4, j=60: 27517.564 / 0.317
# Cost / err at iteration i=4, j=70: 29135.861 / 0.335
# Cost / err at iteration i=4, j=80: 27609.980 / 0.317
# Cost / err at iteration i=4, j=90: 27383.727 / 0.324
# Cost / err at iteration i=4, j=100: 26822.293 / 0.313
# Cost / err at iteration i=4, j=110: 27360.182 / 0.318
# Cost / err at iteration i=4, j=120: 28346.168 / 0.332
# Cost / err at iteration i=4, j=130: 27064.900 / 0.313
# Cost / err at iteration i=4, j=140: 27786.172 / 0.331
# Cost / err at iteration i=5, j=0: 28125.793 / 0.330
# Cost / err at iteration i=5, j=10: 26522.477 / 0.301
# Cost / err at iteration i=5, j=20: 26954.582 / 0.309
# Cost / err at iteration i=5, j=30: 26236.766 / 0.305
# Cost / err at iteration i=5, j=40: 26699.625 / 0.308
# Cost / err at iteration i=5, j=50: 25749.814 / 0.294
# Cost / err at iteration i=5, j=60: 26653.281 / 0.307
# Cost / err at iteration i=5, j=70: 26660.035 / 0.308
# Cost / err at iteration i=5, j=80: 27062.852 / 0.307
# Cost / err at iteration i=5, j=90: 25357.510 / 0.294
# Cost / err at iteration i=5, j=100: 25237.400 / 0.292
# Cost / err at iteration i=5, j=110: 25513.158 / 0.295
# Cost / err at iteration i=5, j=120: 25776.135 / 0.296
# Cost / err at iteration i=5, j=130: 25352.020 / 0.290
# Cost / err at iteration i=5, j=140: 26321.824 / 0.309
# Cost / err at iteration i=6, j=0: 26596.863 / 0.303
# Cost / err at iteration i=6, j=10: 25422.145 / 0.292
# Cost / err at iteration i=6, j=20: 25410.547 / 0.292
# Cost / err at iteration i=6, j=30: 24809.043 / 0.284
# Cost / err at iteration i=6, j=40: 25773.195 / 0.297
# Cost / err at iteration i=6, j=50: 25000.049 / 0.285
# Cost / err at iteration i=6, j=60: 25026.973 / 0.287
# Cost / err at iteration i=6, j=70: 26297.008 / 0.304
# Cost / err at iteration i=6, j=80: 27534.475 / 0.312
# Cost / err at iteration i=6, j=90: 25614.305 / 0.295
# Cost / err at iteration i=6, j=100: 26116.402 / 0.305
# Cost / err at iteration i=6, j=110: 24545.395 / 0.283
# Cost / err at iteration i=6, j=120: 26284.148 / 0.303
# Cost / err at iteration i=6, j=130: 25340.484 / 0.293
# Cost / err at iteration i=6, j=140: 25422.355 / 0.294
# Cost / err at iteration i=7, j=0: 25441.695 / 0.292
# Cost / err at iteration i=7, j=10: 25507.277 / 0.296
# Cost / err at iteration i=7, j=20: 23983.023 / 0.272
# Cost / err at iteration i=7, j=30: 24075.652 / 0.278
# Cost / err at iteration i=7, j=40: 23866.256 / 0.275
# Cost / err at iteration i=7, j=50: 24392.748 / 0.279
# Cost / err at iteration i=7, j=60: 24052.352 / 0.277
# Cost / err at iteration i=7, j=70: 25979.777 / 0.301
# Cost / err at iteration i=7, j=80: 25660.096 / 0.293
# Cost / err at iteration i=7, j=90: 25787.051 / 0.295
# Cost / err at iteration i=7, j=100: 24555.705 / 0.283
# Cost / err at iteration i=7, j=110: 23534.703 / 0.269
# Cost / err at iteration i=7, j=120: 25018.594 / 0.285
# Cost / err at iteration i=7, j=130: 24511.900 / 0.280
# Cost / err at iteration i=7, j=140: 24114.068 / 0.280
# Cost / err at iteration i=8, j=0: 24235.113 / 0.277
# Cost / err at iteration i=8, j=10: 24088.355 / 0.274
# Cost / err at iteration i=8, j=20: 23263.152 / 0.261
# Cost / err at iteration i=8, j=30: 23699.000 / 0.270
# Cost / err at iteration i=8, j=40: 24119.129 / 0.278
# Cost / err at iteration i=8, j=50: 23985.490 / 0.274
# Cost / err at iteration i=8, j=60: 23398.646 / 0.268
# Cost / err at iteration i=8, j=70: 25115.176 / 0.289
# Cost / err at iteration i=8, j=80: 24699.820 / 0.282
# Cost / err at iteration i=8, j=90: 25143.877 / 0.285
# Cost / err at iteration i=8, j=100: 25058.385 / 0.288
# Cost / err at iteration i=8, j=110: 22567.936 / 0.254
# Cost / err at iteration i=8, j=120: 23784.957 / 0.268
# Cost / err at iteration i=8, j=130: 24136.133 / 0.268
# Cost / err at iteration i=8, j=140: 23455.654 / 0.271
# Cost / err at iteration i=9, j=0: 23095.580 / 0.256
# Cost / err at iteration i=9, j=10: 24647.996 / 0.283
# Cost / err at iteration i=9, j=20: 22414.424 / 0.250
# Cost / err at iteration i=9, j=30: 22562.271 / 0.256
# Cost / err at iteration i=9, j=40: 22890.355 / 0.260
# Cost / err at iteration i=9, j=50: 23833.818 / 0.272
# Cost / err at iteration i=9, j=60: 22925.750 / 0.263
# Cost / err at iteration i=9, j=70: 23897.148 / 0.272
# Cost / err at iteration i=9, j=80: 24132.123 / 0.269
# Cost / err at iteration i=9, j=90: 24468.246 / 0.271
# Cost / err at iteration i=9, j=100: 23224.480 / 0.261
# Cost / err at iteration i=9, j=110: 23118.646 / 0.262
# Cost / err at iteration i=9, j=120: 23532.387 / 0.269
# Cost / err at iteration i=9, j=130: 22827.023 / 0.256
# Cost / err at iteration i=9, j=140: 23072.338 / 0.268
# Cost / err at iteration i=10, j=0: 23786.586 / 0.265
# Cost / err at iteration i=10, j=10: 23594.156 / 0.270
# Cost / err at iteration i=10, j=20: 21793.879 / 0.240
# Cost / err at iteration i=10, j=30: 22284.742 / 0.253
# Cost / err at iteration i=10, j=40: 22336.986 / 0.254
# Cost / err at iteration i=10, j=50: 22739.598 / 0.255
# Cost / err at iteration i=10, j=60: 23039.793 / 0.263
# Cost / err at iteration i=10, j=70: 23045.766 / 0.261
# Cost / err at iteration i=10, j=80: 23291.934 / 0.257
# Cost / err at iteration i=10, j=90: 23182.496 / 0.263
# Cost / err at iteration i=10, j=100: 23031.650 / 0.256
# Cost / err at iteration i=10, j=110: 21922.410 / 0.243
# Cost / err at iteration i=10, j=120: 22408.098 / 0.253
# Cost / err at iteration i=10, j=130: 22023.035 / 0.245
# Cost / err at iteration i=10, j=140: 22142.152 / 0.251
# Cost / err at iteration i=11, j=0: 22099.848 / 0.245
# Cost / err at iteration i=11, j=10: 23646.740 / 0.268
# Cost / err at iteration i=11, j=20: 23246.922 / 0.259
# Cost / err at iteration i=11, j=30: 21596.262 / 0.239
# Cost / err at iteration i=11, j=40: 22080.701 / 0.247
# Cost / err at iteration i=11, j=50: 22712.820 / 0.255
# Cost / err at iteration i=11, j=60: 22220.533 / 0.252
# Cost / err at iteration i=11, j=70: 21797.068 / 0.242
# Cost / err at iteration i=11, j=80: 21593.586 / 0.237
# Cost / err at iteration i=11, j=90: 23095.258 / 0.258
# Cost / err at iteration i=11, j=100: 22424.592 / 0.253
# Cost / err at iteration i=11, j=110: 22098.191 / 0.242
# Cost / err at iteration i=11, j=120: 21625.479 / 0.243
# Cost / err at iteration i=11, j=130: 21160.246 / 0.233
# Cost / err at iteration i=11, j=140: 21771.010 / 0.247
# Cost / err at iteration i=12, j=0: 21698.793 / 0.237
# Cost / err at iteration i=12, j=10: 22780.582 / 0.260
# Cost / err at iteration i=12, j=20: 20864.324 / 0.230
# Cost / err at iteration i=12, j=30: 21027.830 / 0.234
# Cost / err at iteration i=12, j=40: 22714.488 / 0.254
# Cost / err at iteration i=12, j=50: 22060.992 / 0.245
# Cost / err at iteration i=12, j=60: 22223.746 / 0.252
# Cost / err at iteration i=12, j=70: 20716.947 / 0.228
# Cost / err at iteration i=12, j=80: 21524.186 / 0.236
# Cost / err at iteration i=12, j=90: 22209.670 / 0.246
# Cost / err at iteration i=12, j=100: 22357.328 / 0.254
# Cost / err at iteration i=12, j=110: 21034.148 / 0.232
# Cost / err at iteration i=12, j=120: 20935.258 / 0.236
# Cost / err at iteration i=12, j=130: 20583.914 / 0.224
# Cost / err at iteration i=12, j=140: 21522.664 / 0.243
# Cost / err at iteration i=13, j=0: 21333.594 / 0.231
# Cost / err at iteration i=13, j=10: 21581.146 / 0.243
# Cost / err at iteration i=13, j=20: 20479.119 / 0.224
# Cost / err at iteration i=13, j=30: 20758.273 / 0.233
# Cost / err at iteration i=13, j=40: 21541.139 / 0.239
# Cost / err at iteration i=13, j=50: 21264.254 / 0.233
# Cost / err at iteration i=13, j=60: 21031.240 / 0.240
# Cost / err at iteration i=13, j=70: 20451.094 / 0.226
# Cost / err at iteration i=13, j=80: 20222.197 / 0.220
# Cost / err at iteration i=13, j=90: 22433.020 / 0.252
# Cost / err at iteration i=13, j=100: 22556.691 / 0.258
# Cost / err at iteration i=13, j=110: 20313.947 / 0.220
# Cost / err at iteration i=13, j=120: 20754.020 / 0.229
# Cost / err at iteration i=13, j=130: 19471.492 / 0.211
# Cost / err at iteration i=13, j=140: 21497.125 / 0.242
# Cost / err at iteration i=14, j=0: 22012.738 / 0.240
# Cost / err at iteration i=14, j=10: 20982.516 / 0.230
# Cost / err at iteration i=14, j=20: 20847.617 / 0.229
# Cost / err at iteration i=14, j=30: 21734.123 / 0.242
# Cost / err at iteration i=14, j=40: 21386.656 / 0.237
# Cost / err at iteration i=14, j=50: 20814.566 / 0.229
# Cost / err at iteration i=14, j=60: 20820.963 / 0.233
# Cost / err at iteration i=14, j=70: 20553.848 / 0.228
# Cost / err at iteration i=14, j=80: 20947.740 / 0.231
# Cost / err at iteration i=14, j=90: 21251.402 / 0.237
# Cost / err at iteration i=14, j=100: 20207.756 / 0.220
# Cost / err at iteration i=14, j=110: 20039.154 / 0.217
# Cost / err at iteration i=14, j=120: 21101.900 / 0.234
# Cost / err at iteration i=14, j=130: 19912.480 / 0.218
# Cost / err at iteration i=14, j=140: 21848.035 / 0.248
# Cost / err at iteration i=15, j=0: 21057.375 / 0.229
# Cost / err at iteration i=15, j=10: 21054.977 / 0.230
# Cost / err at iteration i=15, j=20: 21164.900 / 0.230
# Cost / err at iteration i=15, j=30: 22468.975 / 0.254
# Cost / err at iteration i=15, j=40: 23000.893 / 0.251
# Cost / err at iteration i=15, j=50: 21364.125 / 0.235
# Cost / err at iteration i=15, j=60: 20381.168 / 0.228
# Cost / err at iteration i=15, j=70: 21046.525 / 0.234
# Cost / err at iteration i=15, j=80: 20160.074 / 0.223
# Cost / err at iteration i=15, j=90: 20530.137 / 0.229
# Cost / err at iteration i=15, j=100: 20335.936 / 0.225
# Cost / err at iteration i=15, j=110: 19554.291 / 0.215
# Cost / err at iteration i=15, j=120: 19737.762 / 0.216
# Cost / err at iteration i=15, j=130: 20064.441 / 0.220
# Cost / err at iteration i=15, j=140: 20320.934 / 0.223
# Cost / err at iteration i=16, j=0: 20319.188 / 0.221
# Cost / err at iteration i=16, j=10: 20713.316 / 0.225
# Cost / err at iteration i=16, j=20: 20902.229 / 0.227
# Cost / err at iteration i=16, j=30: 21467.000 / 0.239
# Cost / err at iteration i=16, j=40: 21437.742 / 0.238
# Cost / err at iteration i=16, j=50: 20674.602 / 0.227
# Cost / err at iteration i=16, j=60: 20450.021 / 0.229
# Cost / err at iteration i=16, j=70: 20777.693 / 0.228
# Cost / err at iteration i=16, j=80: 20154.418 / 0.225
# Cost / err at iteration i=16, j=90: 20565.180 / 0.226
# Cost / err at iteration i=16, j=100: 19962.578 / 0.217
# Cost / err at iteration i=16, j=110: 19232.402 / 0.207
# Cost / err at iteration i=16, j=120: 19824.719 / 0.217
# Cost / err at iteration i=16, j=130: 20071.254 / 0.221
# Cost / err at iteration i=16, j=140: 20190.844 / 0.221
# Cost / err at iteration i=17, j=0: 20184.453 / 0.217
# Cost / err at iteration i=17, j=10: 21260.326 / 0.236
# Cost / err at iteration i=17, j=20: 20785.779 / 0.227
# Cost / err at iteration i=17, j=30: 22157.633 / 0.246
# Cost / err at iteration i=17, j=40: 21813.379 / 0.239
# Cost / err at iteration i=17, j=50: 20752.895 / 0.226
# Cost / err at iteration i=17, j=60: 20272.312 / 0.223
# Cost / err at iteration i=17, j=70: 20738.217 / 0.226
# Cost / err at iteration i=17, j=80: 19997.316 / 0.220
# Cost / err at iteration i=17, j=90: 20209.232 / 0.221
# Cost / err at iteration i=17, j=100: 19777.734 / 0.214
# Cost / err at iteration i=17, j=110: 19339.387 / 0.208
# Cost / err at iteration i=17, j=120: 20108.604 / 0.219
# Cost / err at iteration i=17, j=130: 19668.393 / 0.214
# Cost / err at iteration i=17, j=140: 19457.275 / 0.210
# Cost / err at iteration i=18, j=0: 19911.611 / 0.213
# Cost / err at iteration i=18, j=10: 21554.135 / 0.240
# Cost / err at iteration i=18, j=20: 20487.496 / 0.223
# Cost / err at iteration i=18, j=30: 20393.338 / 0.224
# Cost / err at iteration i=18, j=40: 21159.467 / 0.230
# Cost / err at iteration i=18, j=50: 20244.789 / 0.219
# Cost / err at iteration i=18, j=60: 19706.680 / 0.213
# Cost / err at iteration i=18, j=70: 19512.441 / 0.211
# Cost / err at iteration i=18, j=80: 19909.918 / 0.215
# Cost / err at iteration i=18, j=90: 20501.898 / 0.227
# Cost / err at iteration i=18, j=100: 19765.344 / 0.214
# Cost / err at iteration i=18, j=110: 19030.605 / 0.206
# Cost / err at iteration i=18, j=120: 19572.146 / 0.211
# Cost / err at iteration i=18, j=130: 19866.043 / 0.217
# Cost / err at iteration i=18, j=140: 19285.887 / 0.208
# Cost / err at iteration i=19, j=0: 19981.594 / 0.210
# Cost / err at iteration i=19, j=10: 20962.562 / 0.225
# Cost / err at iteration i=19, j=20: 19918.855 / 0.214
# Cost / err at iteration i=19, j=30: 19691.887 / 0.216
# Cost / err at iteration i=19, j=40: 20721.773 / 0.224
# Cost / err at iteration i=19, j=50: 20393.230 / 0.221
# Cost / err at iteration i=19, j=60: 18948.684 / 0.202
# Cost / err at iteration i=19, j=70: 20106.031 / 0.217
# Cost / err at iteration i=19, j=80: 19332.123 / 0.206
# Cost / err at iteration i=19, j=90: 20302.016 / 0.221
# Cost / err at iteration i=19, j=100: 20174.195 / 0.220
# Cost / err at iteration i=19, j=110: 19005.721 / 0.208
# Cost / err at iteration i=19, j=120: 20147.859 / 0.216
# Cost / err at iteration i=19, j=130: 19503.752 / 0.212
# Cost / err at iteration i=19, j=140: 19377.652 / 0.211
# Elapsed time: 0:15:46.528630
